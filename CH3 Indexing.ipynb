# %%
import pandas as pd

# %%
oo = pd.read_csv('data/olympics.csv' , skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# index has own type, is not series or dataframe
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# # set_index()

# %%
# set athelet as set_index
oo.set_index('Athlete')
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred           Men              100m freestyle            M    Gold
# HERSCHMANN, Otto        Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios       Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis      Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon      Men  100m freestyle for sailors            M  Silver
# ...                     ...                         ...          ...     ...
# ENGLICH, Mirko          Men                   84 - 96kg            M  Silver
# MIZGAITIS, Mindaugas    Men                  96 - 120kg            M  Bronze
# PATRIKEEV, Yuri         Men                  96 - 120kg            M  Bronze
# LOPEZ, Mijain           Men                  96 - 120kg            M    Gold
# BAROEV, Khasan          Men                  96 - 120kg            M  Silver
#
# [29216 rows x 9 columns]

# %%
# we can figur out nothing change
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# so if we want to change in orignal dataframe we should use inplace 
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %% [markdown]
# # reset_index()

# %%
# the opposite of set_index, it return the datafram with default index
oo.reset_index(inplace=True)
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# # sort_index()

# %%
#alows all item to sorted by specific index. We can sort objects by a lable along the axis
oo.sort_index(inplace=True)
oo.head()
# Out:
#                           index     City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651    Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730   London     1948  Gymnastics  Artistic G.
#
#                           NOC Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar              ZZX    Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian     FIN    Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian     FIN    Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes  FIN    Men   team competition            M    Gold

# %% [markdown]
# #  loc[]
# <ul>
#     <li>DataFrame.loc[] / DataFrame.Series.loc[]</li>
#     <li>A label-based indexer for selection by lable</li>
#     <li>loc[] will raise a KeyError when the items are not found</li>
# </ul>

# %%
oo.set_index('Athlete', inplace=True)
oo.loc['BOLT, Usain']
# Out:
#              level_0  index     City  Edition      Sport Discipline  NOC  \
# Athlete
# BOLT, Usain     2450  27570  Beijing     2008  Athletics  Athletics  JAM
# BOLT, Usain     2451  27603  Beijing     2008  Athletics  Athletics  JAM
# BOLT, Usain     2452  27552  Beijing     2008  Athletics  Athletics  JAM
#
#             Gender         Event Event_gender Medal
# Athlete
# BOLT, Usain    Men          200m            M  Gold
# BOLT, Usain    Men  4x100m relay            M  Gold
# BOLT, Usain    Men          100m            M  Gold

# %%
oo.reset_index(inplace=True)
oo.head()
# Out:
#                     Athlete  level_0  index     City  Edition       Sport  \
# 0              AABYE, Edgar        0    651    Paris     1900  Tug of War
# 1     AALTONEN, Arvo Ossian        1   2849  Antwerp     1920    Aquatics
# 2     AALTONEN, Arvo Ossian        2   2852  Antwerp     1920    Aquatics
# 3  AALTONEN, Paavo Johannes        3   7716   London     1948  Gymnastics
# 4  AALTONEN, Paavo Johannes        4   7730   London     1948  Gymnastics
#
#     Discipline  NOC Gender              Event Event_gender   Medal
# 0   Tug of War  ZZX    Men         tug of war            M    Gold
# 1     Swimming  FIN    Men  200m breaststroke            M  Bronze
# 2     Swimming  FIN    Men  400m breaststroke            M  Bronze
# 3  Artistic G.  FIN    Men       pommel horse            M    Gold
# 4  Artistic G.  FIN    Men   team competition            M    Gold

# %%
oo.loc[oo.Athlete == 'BOLT, Usain']
# Out:
#           Athlete  level_0  index     City  Edition      Sport Discipline  \
# 2450  BOLT, Usain     2450  27570  Beijing     2008  Athletics  Athletics
# 2451  BOLT, Usain     2451  27603  Beijing     2008  Athletics  Athletics
# 2452  BOLT, Usain     2452  27552  Beijing     2008  Athletics  Athletics
#
#       NOC Gender         Event Event_gender Medal
# 2450  JAM    Men          200m            M  Gold
# 2451  JAM    Men  4x100m relay            M  Gold
# 2452  JAM    Men          100m            M  Gold

# %% [markdown]
# #  iloc[]
# <ul>
#     <li>DataFram.iloc[]</li>
#     <li>iloc[] is primarily integer position based from 0 to length -a of the axis</li>
#     <li>Allows traditional Pythonic slicing</li>
# </ul>

# %%
oo.head()
# Out:
#                     Athlete  level_0  index     City  Edition       Sport  \
# 0              AABYE, Edgar        0    651    Paris     1900  Tug of War
# 1     AALTONEN, Arvo Ossian        1   2849  Antwerp     1920    Aquatics
# 2     AALTONEN, Arvo Ossian        2   2852  Antwerp     1920    Aquatics
# 3  AALTONEN, Paavo Johannes        3   7716   London     1948  Gymnastics
# 4  AALTONEN, Paavo Johannes        4   7730   London     1948  Gymnastics
#
#     Discipline  NOC Gender              Event Event_gender   Medal
# 0   Tug of War  ZZX    Men         tug of war            M    Gold
# 1     Swimming  FIN    Men  200m breaststroke            M  Bronze
# 2     Swimming  FIN    Men  400m breaststroke            M  Bronze
# 3  Artistic G.  FIN    Men       pommel horse            M    Gold
# 4  Artistic G.  FIN    Men   team competition            M    Gold

# %%
oo.iloc[1700]
# Out:
# Athlete         BEKKEVOLD, Kristin
# level_0                       1700
# index                        24256
# City                        Sydney
# Edition                       2000
# Sport                     Football
# Discipline                Football
# NOC                            NOR
# Gender                       Women
# Event                     football
# Event_gender                     W
# Medal                         Gold
# Name: 1700, dtype: object

# %%
oo.iloc[[200, 2, 15, 800]]
# Out:
#                               Athlete  level_0  index      City  Edition  \
# 200                 AICEGA, Magdalena      200  24561    Sydney     2000
# 2               AALTONEN, Arvo Ossian        2   2852   Antwerp     1920
# 15                   ABAJO, Jose Luis       15  28134   Beijing     2008
# 800  ARMSTRONG, Michael Taylor (Tate)      800  14224  Montreal     1976
#
#           Sport  Discipline  NOC Gender              Event Event_gender  \
# 200      Hockey      Hockey  ARG  Women             hockey            W
# 2      Aquatics    Swimming  FIN    Men  400m breaststroke            M
# 15      Fencing     Fencing  ESP    Men    épée individual            M
# 800  Basketball  Basketball  USA    Men         basketball            M
#
#       Medal
# 200  Silver
# 2    Bronze
# 15   Bronze
# 800    Gold

# %%
oo.iloc[1:4]
# Out:
#                     Athlete  level_0  index     City  Edition       Sport  \
# 1     AALTONEN, Arvo Ossian        1   2849  Antwerp     1920    Aquatics
# 2     AALTONEN, Arvo Ossian        2   2852  Antwerp     1920    Aquatics
# 3  AALTONEN, Paavo Johannes        3   7716   London     1948  Gymnastics
#
#     Discipline  NOC Gender              Event Event_gender   Medal
# 1     Swimming  FIN    Men  200m breaststroke            M  Bronze
# 2     Swimming  FIN    Men  400m breaststroke            M  Bronze
# 3  Artistic G.  FIN    Men       pommel horse            M    Gold
