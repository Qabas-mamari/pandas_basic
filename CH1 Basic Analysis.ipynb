# %%
# import Pandas
import pandas as pd

# %% [markdown]
# ## Series and DataFrames

# %%
# List Our Olympics dataframe
oo = pd.read_csv('data/olympics.csv' , skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### Acessing Series
# #### List any column using both the ['..'] and dot notation. what type is this objects?

# %%
oo['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
oo.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
oo[['City', 'Athlete', 'Edition']]
# Out:
#           City               Athlete  Edition
# 0       Athens         HAJOS, Alfred     1896
# 1       Athens      HERSCHMANN, Otto     1896
# 2       Athens     DRIVAS, Dimitrios     1896
# 3       Athens    MALOKINIS, Ioannis     1896
# 4       Athens    CHASAPIS, Spiridon     1896
# ...        ...                   ...      ...
# 29211  Beijing        ENGLICH, Mirko     2008
# 29212  Beijing  MIZGAITIS, Mindaugas     2008
# 29213  Beijing       PATRIKEEV, Yuri     2008
# 29214  Beijing         LOPEZ, Mijain     2008
# 29215  Beijing        BAROEV, Khasan     2008
#
# [29216 rows x 3 columns]

# %%
# the file is dataframe type 
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
# the columns is series 
type(oo.City)
# Out:
# pandas.core.series.Series

# %%
type(oo[['City', 'Athlete', 'Edition']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Data Input and Validations

# %% [markdown]
# ### shape

# %%
oo.shape
# Out:
# (29216, 10)

# %%
# for number of rows 
oo.shape[0]
# Out:
# 29216

# %%
# for number of columns 
oo.shape[1]
# Out:
# 10

# %% [markdown]
# ### head() & tail()

# %%
oo.head() # first 5 rows
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.tail() # last 5 rows
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
# 5             1200m freestyle            M  Bronze
# 6             1200m freestyle            M    Gold
# 7             1200m freestyle            M  Silver
# 8              400m freestyle            M  Bronze
# 9              400m freestyle            M    Gold

# %%
oo.tail(10)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R      MINGUZZI, Andrea
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R         FODOR, Zoltan
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R       MAMBETOV, Asset
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R         WHEELER, Adam
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R    KHUSHTOV, Aslanbek
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29206  ITA    Men   74 - 84kg            M    Gold
# 29207  HUN    Men   74 - 84kg            M  Silver
# 29208  KAZ    Men   84 - 96kg            M  Bronze
# 29209  USA    Men   84 - 96kg            M  Bronze
# 29210  RUS    Men   84 - 96kg            M    Gold
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %% [markdown]
# ### info()

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Basic analysis

# %% [markdown]
# ### value_counts()

# %%
oo.Edition.value_counts() # for both Femail and mail
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
oo.Athlete.sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by=['Athlete']).head(10)
# Out:
#            City  Edition       Sport   Discipline                   Athlete  \
# 651       Paris     1900  Tug of War   Tug of War              AABYE, Edgar
# 2849    Antwerp     1920    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 2852    Antwerp     1920    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 7716     London     1948  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 7730     London     1948  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 7773     London     1948  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 7709     London     1948  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 8563   Helsinki     1952  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 28460   Beijing     2008    Handball     Handball          AAMODT, Ragnhild
# 3436    Antwerp     1920  Gymnastics  Artistic G.          AANING, Alf Lied
#
#        NOC Gender                 Event Event_gender   Medal
# 651    ZZX    Men            tug of war            M    Gold
# 2849   FIN    Men     200m breaststroke            M  Bronze
# 2852   FIN    Men     400m breaststroke            M  Bronze
# 7716   FIN    Men          pommel horse            M    Gold
# 7730   FIN    Men      team competition            M    Gold
# 7773   FIN    Men                 vault            M    Gold
# 7709   FIN    Men  individual all-round            M  Bronze
# 8563   FIN    Men      team competition            M  Bronze
# 28460  NOR  Women              handball            W    Gold
# 3436   NOR    Men     team, free system            M  Silver

# %% [markdown]
# ### Boolean indexing

# %%
gold = oo.Medal == 'Gold'
gold.head(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: Medal, dtype: bool

# %%
oo[oo.Medal == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
#       Gender                       Event Event_gender Medal
# 0        Men              100m freestyle            M  Gold
# 3        Men  100m freestyle for sailors            M  Gold
# 6        Men             1200m freestyle            M  Gold
# 9        Men              400m freestyle            M  Gold
# 13       Men                        100m            M  Gold
# ...      ...                         ...          ...   ...
# 29199    Men                   60 - 66kg            M  Gold
# 29203    Men                   66 - 74kg            M  Gold
# 29206    Men                   74 - 84kg            M  Gold
# 29210    Men                   84 - 96kg            M  Gold
# 29214    Men                  96 - 120kg            M  Gold
#
# [9850 rows x 10 columns]

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...                      ...  ...    ...
# 29134               CAO, Lei  CHN  Women
# 29147           HUYNH, Carol  CAN  Women
# 29155         YOSHIDA, Saori  JPN  Women
# 29163            ICHO, Kaori  JPN  Women
# 29171             WANG, Jiao  CHN  Women
#
#                                          Event Event_gender Medal
# 417                                 individual            W  Gold
# 641                              mixed doubles            X  Gold
# 649                                    singles            W  Gold
# 710    double columbia round (50y - 40y - 30y)            W  Gold
# 713          double national round (60y - 50y)            W  Gold
# ...                                        ...          ...   ...
# 29134                                     75kg            W  Gold
# 29147                                   - 48kg            W  Gold
# 29155                                48 - 55kg            W  Gold
# 29163                                55 - 63kg            W  Gold
# 29171                                63 - 72kg            W  Gold
#
# [2485 rows x 10 columns]

# %% [markdown]
# ### String handling

# %%
oo[oo.Athlete.str.contains("Charlotte")] # if we are looking for full name of someone his name contains Charlotte
# Out:
#               City  Edition       Sport  Discipline                   Athlete  \
# 641          Paris     1900      Tennis      Tennis         COOPER, Charlotte
# 649          Paris     1900      Tennis      Tennis         COOPER, Charlotte
# 1186        London     1908     Archery     Archery            DOD, Charlotte
# 2872       Antwerp     1920    Aquatics    Swimming      RADCLIFFE, Charlotte
# 5034     Amsterdam     1928    Aquatics    Swimming           MÜHE, Charlotte
# 14276     Montreal     1976  Basketball  Basketball          LEWIS, Charlotte
# 17786  Los Angeles     1984      Rowing      Rowing  KOEFOED, Inger Charlotte
# 17816  Los Angeles     1984      Rowing      Rowing    GEER, Charlotte Mosher
# 20371    Barcelona     1992  Equestrian    Dressage        BREDAHL, Charlotte
#
#        NOC Gender                                Event Event_gender   Medal
# 641    GBR  Women                        mixed doubles            X    Gold
# 649    GBR  Women                              singles            W    Gold
# 1186   GBR  Women           national round (60y - 50y)            W  Silver
# 2872   GBR  Women               4x100m freestyle relay            W  Silver
# 5034   GER  Women                    200m breaststroke            W  Bronze
# 14276  USA  Women                           basketball            W  Silver
# 17786  DEN  Women  quadruple sculls with coxswain (4x)            W  Bronze
# 17816  USA  Women                   single sculls (1x)            W  Silver
# 20371  USA  Women                                 team            X  Bronze
